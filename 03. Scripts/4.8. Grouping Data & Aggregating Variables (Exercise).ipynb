# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Data Set

# %%
#Create Path
path = r'C:\Users\praha\OneDrive\Documents\Python\02-2023 Instachart Basket Analysis'

# %%
#import dataframe 'orders_products_merged_2.pkl'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
#create subset of the first one million entries
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge
# ...

# %%
df.groupby('product_name')

# %%
#calculate the mean of the 'order_number' column grouped by the 'department_id' column with agg()
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
#calculate the mean of the 'order_number' column grouped by the 'department_id' column with mean()
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
df.groupby('department_id')['order_number'].count()
# Out:
# department_id
# 1     107229
# 2        717
# 3      15881
# 4     122232
# 5       9197
# 6      13102
# 7     101708
# 8       5309
# 9      31467
# 10      2678
# 11     16258
# 12     15066
# 13     69395
# 14     32244
# 15     66561
# 16    222637
# 17     45075
# 18     19776
# 19     79147
# 20     23109
# 21      1212
# Name: order_number, dtype: int64

# %%
#another command for mean()
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
#perform multiple aggregations
df.groupby('department_id').agg({'order_number':['mean', 'min', 'max', 'count']})
# Out:
#               order_number
#                       mean min max   count
# department_id
# 1                15.577493   1  99  107229
# 2                17.320781   1  96     717
# 3                16.084944   1  99   15881
# 4                17.530458   1  99  122232
# 5                14.763075   1  99    9197
# 6                16.658449   1  99   13102
# 7                17.031590   1  99  101708
# 8                15.076662   1  98    5309
# 9                15.447580   1  99   31467
# 10               18.681852   1  99    2678
# 11               15.447411   1  99   16258
# 12               14.327957   1  99   15066
# 13               16.548642   1  99   69395
# 14               16.960241   1  99   32244
# 15               16.121948   1  99   66561
# 16               17.803851   1  99  222637
# 17               15.593633   1  99   45075
# 18               19.674252   1  99   19776
# 19               16.899756   1  99   79147
# 20               16.255442   1  99   23109
# ...

# %%
#agggregate data with transform()
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal_customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular_customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New_customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular_customer    15876776
# Loyal_customer      10284093
# New_customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular_customer            28
# 1       138  Regular_customer            30
# 2       709      New_customer             2
# 3       764      New_customer             1
# 4       764      New_customer             3
# 5       777  Regular_customer            16
# 6       825      New_customer             3
# 7       910  Regular_customer            12
# 8      1052  Regular_customer            10
# 9      1052  Regular_customer            15
# 10     1379      New_customer             1
# 11     1480    Loyal_customer            36
# 12     1480    Loyal_customer            38
# 13     1480    Loyal_customer            39
# 14     1494  Regular_customer             6
# 15     1494  Regular_customer             7
# 16     1494  Regular_customer             9
# 17     1540  Regular_customer             4
# 18     1540  Regular_customer             5
# 19     1540  Regular_customer             6
# ...
